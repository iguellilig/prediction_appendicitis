# %%
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import resample
import numpy as np
from imblearn.over_sampling import SMOTE
import joblib

# random seed
seed = 123

# %%
# Read original dataset
data_df = pd.read_csv("data/data.csv")
data_df.sample(frac=1, random_state=seed)
data_df = data_df.dropna(subset=["Diagnosis"])
data_df.fillna(-1, inplace = True)
data_df = data_df[['Age', 
             'BMI', 
             'Sex', 
             'Height',
             'Weight',
             'Appendix_Diameter',
             'Migratory_Pain', 
             'Lower_Right_Abd_Pain',
             'Contralateral_Rebound_Tenderness',
             'Coughing_Pain',
             'Loss_of_Appetite',
             'Body_Temperature',
             'WBC_Count',
             'Neutrophil_Percentage',
             'Segmented_Neutrophils',
             'Neutrophilia',
             'RBC_Count',
             'Hemoglobin',
             'RDW',
             'Thrombocyte_Count',
             'Ketones_in_Urine',
             'RBC_in_Urine',
             'WBC_in_Urine',
             'CRP',
             'Dysuria',
             'Stool',
             'Peritonitis',
             'Psoas_Sign',
             'Diagnosis'
            ]]
    
val_map = [('Sex', {'male':0, 'female':1}), 
                    ('Migratory_Pain', {'yes': 2, 'no':3}), 
                    ('Lower_Right_Abd_Pain', {'yes': 2, 'no':3}),
                    ('Contralateral_Rebound_Tenderness', {'yes': 2, 'no':3}),
                    ('Coughing_Pain', {'yes': 2, 'no':3}),
                    ('Loss_of_Appetite', {'yes': 2, 'no':3}),
                    ('Neutrophilia', {'yes': 2, 'no':3}),
                    ('Ketones_in_Urine', {'no': 3, '+':4, '++':5, '+++':6}),
                    ('RBC_in_Urine', {'no': 3, '+':4, '++':5, '+++':6}),
                    ('WBC_in_Urine', {'no': 3, '+':4, '++':5, '+++':6}),
                    ('Dysuria', {'yes': 2, 'no':3}),
                    ('Stool', {'normal': 7, 'constipation':8, 'diarrhea':9, 'constipation, diarrhea':10}),
                    ('Peritonitis', {'no': 3, 'local':11, 'generalized':12}),
                    ('Psoas_Sign', {'yes': 2, 'no':3}),
                    ('Diagnosis', {'appendicitis':1, 'no appendicitis': 0})]
for column, themap in val_map:
    data_df[column] = data_df[column].replace(themap)
print(data_df)
    
#X = X.astype(float)
#X = X.round(3)
# Out:
#       Age   BMI  Sex  Height  Weight  Appendix_Diameter  Migratory_Pain  \
# 0   12.68 16.90    1  148.00   37.00               7.10               3
# 1   14.10 31.90    0  147.00   69.50              -1.00               2
# 2   14.14 23.30    1  163.00   62.00              -1.00               3
# 3   16.37 20.60    1  165.00   56.00              -1.00               2
# 4   11.08 16.90    1  163.00   45.00               7.00               3
# ..    ...   ...  ...     ...     ...                ...             ...
# 777 12.41 25.25    1  166.50   70.00               7.50               2
# 778 17.09 20.43    1  158.00   51.00              -1.00               3
# 779 14.99 19.91    1  152.00   46.00              -1.00               3
# 780  7.20 14.30    0  129.30   23.90              14.00               2
# 781 11.51 18.17    0  146.50   39.00               8.00               3
#
#      Lower_Right_Abd_Pain  Contralateral_Rebound_Tenderness  Coughing_Pain  \
# 0                       2                                 2              3
# 1                       2                                 2              3
# 2                       2                                 2              3
# 3                       2                                 3              3
# 4                       2                                 2              2
# ..                    ...                               ...            ...
# 777                     2                                 3              3
# 778                     3                                 3              3
# 779                     2                                 3              3
# 780                     2                                 3              2
# 781                     2                                 3              3
#
#      ...  Thrombocyte_Count  Ketones_in_Urine  RBC_in_Urine  WBC_in_Urine  \
# 0    ...             254.00                 5             4             3
# 1    ...             151.00                 3             3             3
# 2    ...             300.00                 3             3             3
# 3    ...             258.00                 3             3             3
# 4    ...             311.00                 3             3             3
# ..   ...                ...               ...           ...           ...
# 777  ...             243.00                -1            -1            -1
# 778  ...             310.00                -1            -1            -1
# 779  ...             328.00                 3             3             3
# 780  ...             345.00                 6             3             3
# 781  ...             291.00                 3             3             3
#
#        CRP  Dysuria  Stool  Peritonitis  Psoas_Sign  Diagnosis
# 0     0.00        3      7            3           2          1
# 1     3.00        2      7            3           2          0
# 2     3.00        3      8            3           2          0
# 3     0.00        2      7            3           2          0
# 4     0.00        3      8            3           2          1
# ..     ...      ...    ...          ...         ...        ...
# 777  71.00        3      9           11           2          1
# 778 245.00        3      7           11           3          1
# 779   2.00        2      7            3           3          1
# 780   8.00        3      7           11           3          1
# 781   1.00        3      7           11           3          1
#
# [780 rows x 29 columns]

# %%
'''#Random oversampling
minority_class = data_df[data_df["Diagnosis"] == 0]
majority_class = data_df[data_df["Diagnosis"] == 1]
minority_upsampled = resample(minority_class, replace=True, n_samples=len(majority_class),random_state=42)
balanced_data = pd.concat([majority_class, minority_upsampled])
data_df = balanced_data
print(data_df)'''
# Out:
#       Age   BMI  Sex  Height  Weight  Appendix_Diameter  Migratory_Pain  \
# 0   12.68 16.90    1  148.00   37.00               7.10               3
# 4   11.08 16.90    1  163.00   45.00               7.00               3
# 9   14.34 14.90    0  174.00   45.50               8.00               3
# 10  11.87 15.70    0  147.00   34.00               9.00               2
# 14  15.98 19.70    1  164.00   53.00               9.00               3
# ..    ...   ...  ...     ...     ...                ...             ...
# 160 14.11 18.50    1  156.00   45.00              -1.00               3
# 155 14.99 20.80    1  161.00   54.00               5.10               3
# 197 16.58 18.80    1  158.00   47.00              -1.00               3
# 179 17.30 22.70    0  173.00   68.00               4.00               3
# 324  6.67 25.04    1  124.00   38.50               3.50               3
#
#      Lower_Right_Abd_Pain  Contralateral_Rebound_Tenderness  Coughing_Pain  \
# 0                       2                                 2              3
# 4                       2                                 2              2
# 9                       2                                 3              3
# 10                      2                                 3              2
# 14                      2                                 2              2
# ..                    ...                               ...            ...
# 160                     2                                 2              2
# 155                     2                                 3              3
# 197                     2                                 3              3
# 179                     2                                 2              2
# 324                     2                                 2              3
#
#      ...  Thrombocyte_Count  Ketones_in_Urine  RBC_in_Urine  WBC_in_Urine  \
# 0    ...             254.00                 5             4             3
# 4    ...             311.00                 3             3             3
# 9    ...             220.00                 3             3             3
# 10   ...             319.00                 3             3             3
# 14   ...             245.00                -1            -1            -1
# ..   ...                ...               ...           ...           ...
# 160  ...             344.00                 3             3             3
# 155  ...             307.00                -1            -1            -1
# 197  ...             352.00                 5            -1             3
# 179  ...             168.00                -1            -1            -1
# 324  ...             444.00                 4             3             3
#
#       CRP  Dysuria  Stool  Peritonitis  Psoas_Sign  Diagnosis
# 0    0.00        3      7            3           2          1
# 4    0.00        3      8            3           2          1
# 9    0.00        3      7            3           3          1
# 10  17.00        3      7            3           3          1
# 14   5.00        3      7            3           3          1
# ..    ...      ...    ...          ...         ...        ...
# 160  1.00        3      7            3           2          0
# 155  0.00        3      7            3           3          0
# 197 11.00        3      7            3           3          0
# 179  0.00        3      7            3           2          0
# 324 21.00        3      9            3           3          0
#
# [926 rows x 29 columns]

# %%
#Random undersampling
minority_class = data_df[data_df["Diagnosis"] == 0]
majority_class = data_df[data_df["Diagnosis"] == 1]
majority_downsampled = resample(majority_class, replace=False, n_samples=len(minority_class),random_state=42)
balanced_data = pd.concat([minority_class, majority_downsampled])
data_df = balanced_data
print(data_df)
# Out:
#       Age   BMI  Sex  Height  Weight  Appendix_Diameter  Migratory_Pain  \
# 1   14.10 31.90    0  147.00   69.50              -1.00               2
# 2   14.14 23.30    1  163.00   62.00              -1.00               3
# 3   16.37 20.60    1  165.00   56.00              -1.00               2
# 5   11.05 30.70    0  121.00   45.00              -1.00               2
# 6    8.98 19.40    1  140.00   38.50              -1.00               3
# ..    ...   ...  ...     ...     ...                ...             ...
# 537  9.04 16.33    1  140.00   32.00              11.00               3
# 237  8.67 15.99    1  133.50   28.50               8.00               3
# 118 12.59 16.70    0  148.50   36.50               7.50               3
# 556  8.20 13.75    1  133.50   24.50               8.00               3
# 722 11.38 21.08    0  154.00   50.00              12.00               3
#
#      Lower_Right_Abd_Pain  Contralateral_Rebound_Tenderness  Coughing_Pain  \
# 1                       2                                 2              3
# 2                       2                                 2              3
# 3                       2                                 3              3
# 5                       2                                 2              2
# 6                       2                                 2              2
# ..                    ...                               ...            ...
# 537                     2                                 3              3
# 237                     2                                 2              3
# 118                     2                                 3              3
# 556                     2                                 3              3
# 722                     2                                 3              2
#
#      ...  Thrombocyte_Count  Ketones_in_Urine  RBC_in_Urine  WBC_in_Urine  \
# 1    ...             151.00                 3             3             3
# 2    ...             300.00                 3             3             3
# 3    ...             258.00                 3             3             3
# 5    ...             249.00                 5             3             3
# 6    ...             337.00                 3             3             4
# ..   ...                ...               ...           ...           ...
# 537  ...              -1.00                 3             3             3
# 237  ...             295.00                 3             3             3
# 118  ...             297.00                 3             3             3
# 556  ...             285.00                 5             4             3
# 722  ...             362.00                 3             3             3
#
#       CRP  Dysuria  Stool  Peritonitis  Psoas_Sign  Diagnosis
# 1    3.00        2      7            3           2          0
# 2    3.00        3      8            3           2          0
# 3    0.00        2      7            3           2          0
# 5   63.00        3      9            3           2          0
# 6    9.00        3      7            3           2          0
# ..    ...      ...    ...          ...         ...        ...
# 537 23.00        3      7            3           3          1
# 237 20.00        3      7            3           3          1
# 118 11.00        3      7            3           3          1
# 556  6.00        3      7            3           3          1
# 722 38.00        3      7           11           3          1
#
# [634 rows x 29 columns]

# %%
X = data_df[['Age', 
             'BMI', 
             'Sex', 
             'Height',
             'Weight',
             'Appendix_Diameter',
             'Migratory_Pain', 
             'Lower_Right_Abd_Pain',
             'Contralateral_Rebound_Tenderness',
             'Coughing_Pain',
             'Loss_of_Appetite',
             'Body_Temperature',
             'WBC_Count',
             'Neutrophil_Percentage',
             'Segmented_Neutrophils',
             'Neutrophilia',
             'RBC_Count',
             'Hemoglobin',
             'RDW',
             'Thrombocyte_Count',
             'Ketones_in_Urine',
             'RBC_in_Urine',
             'WBC_in_Urine',
             'CRP',
             'Dysuria',
             'Stool',
             'Peritonitis',
             'Psoas_Sign'
            ]]
             
y = data_df[['Diagnosis']]

# split data into train and test sets
# 70% training and 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=seed, stratify=y)

# %%
X_train["Diagnosis"] = y_train["Diagnosis"]


#Random oversampling
minority_class = X_train[X_train["Diagnosis"] == 0]
majority_class = X_train[X_train["Diagnosis"] == 1]
minority_upsampled = resample(minority_class, replace=True, n_samples=len(majority_class),random_state=42)
balanced_data = pd.concat([majority_class, minority_upsampled])
X_train = balanced_data
y_train = X_train["Diagnosis"]
X_train = X_train.drop(columns=["Diagnosis"])


X_train.to_csv("data/train_sample_over.csv")
y_train.to_csv("data/train_diagnosis_over.csv")
X_test.to_csv("data/test_sample_over.csv")
y_test.to_csv("data/test_diagnosis_over.csv")

# %%
X_train["Diagnosis"] = y_train["Diagnosis"]

# Synthetic Minority Over-sampling Technique (SMOTE)
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

y_train = X_train["Diagnosis"]
X_train = X_train.drop(columns=["Diagnosis"])

X_train.to_csv("data/train_sample_smote.csv")
y_train.to_csv("data/train_diagnosis_smote.csv")
X_test.to_csv("data/test_sample_smote.csv")
y_test.to_csv("data/test_diagnosis_smote.csv")

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
with open("results_models/results_lazypredict.txt", "w") as file_write:
    file_write.write(str(models))
# Out:
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 17.39it/s]
# [LightGBM] [Info] Number of positive: 370, number of negative: 370
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000389 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2349
# [LightGBM] [Info] Number of data points in the train set: 740, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.92               0.93     0.93      0.92
# BaggingClassifier                  0.92               0.92     0.92      0.92
# LGBMClassifier                     0.91               0.92     0.92      0.91
# ExtraTreesClassifier               0.91               0.92     0.92      0.91
# XGBClassifier                      0.90               0.90     0.90      0.90
# AdaBoostClassifier                 0.87               0.87     0.87      0.87
# DecisionTreeClassifier             0.86               0.86     0.86      0.86
# LinearSVC                          0.85               0.86     0.86      0.85
# LogisticRegression                 0.85               0.86     0.86      0.85
# SVC                                0.85               0.85     0.85      0.85
# CalibratedClassifierCV             0.83               0.84     0.84      0.83
# NuSVC                              0.83               0.84     0.84      0.83
# SGDClassifier                      0.82               0.83     0.83      0.82
# LinearDiscriminantAnalysis         0.81               0.83     0.83      0.82
# RidgeClassifier                    0.81               0.83     0.83      0.82
# RidgeClassifierCV                  0.81               0.83     0.83      0.82
# NearestCentroid                    0.79               0.81     0.81      0.80
# KNeighborsClassifier               0.79               0.80     0.80      0.79
# Perceptron                         0.77               0.78     0.78      0.77
# ExtraTreeClassifier                0.78               0.77     0.77      0.78
# BernoulliNB                        0.75               0.76     0.76      0.75
# PassiveAggressiveClassifier        0.74               0.75     0.75      0.74
# QuadraticDiscriminantAnalysis      0.72               0.75     0.75      0.72
# GaussianNB                         0.70               0.74     0.74      0.69
# LabelSpreading                     0.72               0.74     0.74      0.73
# LabelPropagation                   0.72               0.74     0.74      0.73
# DummyClassifier                    0.40               0.50     0.50      0.23
#
#                                Time Taken
# Model
# RandomForestClassifier               0.22
# BaggingClassifier                    0.06
# LGBMClassifier                       0.24
# ExtraTreesClassifier                 0.16
# XGBClassifier                        0.14
# AdaBoostClassifier                   0.16
# DecisionTreeClassifier               0.02
# LinearSVC                            0.04
# LogisticRegression                   0.02
# SVC                                  0.04
# CalibratedClassifierCV               0.17
# NuSVC                                0.04
# SGDClassifier                        0.02
# LinearDiscriminantAnalysis           0.02
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# NearestCentroid                      0.01
# KNeighborsClassifier                 0.02
# Perceptron                           0.01
# ExtraTreeClassifier                  0.02
# BernoulliNB                          0.02
# PassiveAggressiveClassifier          0.02
# QuadraticDiscriminantAnalysis        0.02
# GaussianNB                           0.02
# LabelSpreading                       0.05
# LabelPropagation                     0.05
# DummyClassifier                      0.01

# %%
#Cross validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
count = 1
for train_idx, test_idx in cv.split(X,y):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
    models,predictions = clf.fit(X_train, X_test, y_train, y_test)
    print(models)
    
    with open("results_models/results_lazypredict_cross"+str(count)+".txt", "w") as file_write:
        file_write.write(str(models))
        count = count + 1
# Out:
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 18.62it/s]
# [LightGBM] [Info] Number of positive: 370, number of negative: 254
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1566
# [LightGBM] [Info] Number of data points in the train set: 624, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.592949 -> initscore=0.376169
# [LightGBM] [Info] Start training from score 0.376169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.90               0.89     0.89      0.90
# RandomForestClassifier             0.90               0.88     0.88      0.90
# BaggingClassifier                  0.88               0.87     0.87      0.88
# ExtraTreesClassifier               0.88               0.87     0.87      0.88
# LinearDiscriminantAnalysis         0.87               0.87     0.87      0.87
# RidgeClassifier                    0.87               0.87     0.87      0.87
# XGBClassifier                      0.88               0.87     0.87      0.88
# RidgeClassifierCV                  0.86               0.87     0.87      0.86
# SVC                                0.85               0.85     0.85      0.85
# CalibratedClassifierCV             0.85               0.85     0.85      0.85
# NuSVC                              0.85               0.85     0.85      0.85
# LogisticRegression                 0.85               0.85     0.85      0.85
# LinearSVC                          0.85               0.85     0.85      0.85
# AdaBoostClassifier                 0.85               0.84     0.84      0.85
# Perceptron                         0.84               0.83     0.83      0.84
# KNeighborsClassifier               0.83               0.83     0.83      0.83
# ExtraTreeClassifier                0.82               0.82     0.82      0.82
# DecisionTreeClassifier             0.82               0.81     0.81      0.82
# SGDClassifier                      0.80               0.80     0.80      0.80
# LabelSpreading                     0.78               0.79     0.79      0.78
# LabelPropagation                   0.78               0.79     0.79      0.78
# NearestCentroid                    0.76               0.78     0.78      0.76
# BernoulliNB                        0.75               0.75     0.75      0.75
# PassiveAggressiveClassifier        0.78               0.74     0.74      0.76
# QuadraticDiscriminantAnalysis      0.69               0.73     0.73      0.69
# GaussianNB                         0.65               0.70     0.70      0.64
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# LGBMClassifier                       0.09
# RandomForestClassifier               0.21
# BaggingClassifier                    0.08
# ExtraTreesClassifier                 0.16
# LinearDiscriminantAnalysis           0.02
# RidgeClassifier                      0.02
# XGBClassifier                        0.13
# RidgeClassifierCV                    0.02
# SVC                                  0.04
# CalibratedClassifierCV               0.22
# NuSVC                                0.05
# LogisticRegression                   0.04
# LinearSVC                            0.05
# AdaBoostClassifier                   0.14
# Perceptron                           0.02
# KNeighborsClassifier                 0.02
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.02
# SGDClassifier                        0.01
# LabelSpreading                       0.04
# LabelPropagation                     0.04
# NearestCentroid                      0.01
# BernoulliNB                          0.02
# PassiveAggressiveClassifier          0.02
# QuadraticDiscriminantAnalysis        0.01
# GaussianNB                           0.01
# DummyClassifier                      0.02
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 20.13it/s]
# [LightGBM] [Info] Number of positive: 370, number of negative: 254
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1579
# [LightGBM] [Info] Number of data points in the train set: 624, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.592949 -> initscore=0.376169
# [LightGBM] [Info] Start training from score 0.376169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.94               0.93     0.93      0.94
# LGBMClassifier                     0.92               0.92     0.92      0.92
# AdaBoostClassifier                 0.92               0.91     0.91      0.92
# RandomForestClassifier             0.92               0.91     0.91      0.92
# BaggingClassifier                  0.90               0.89     0.89      0.90
# ExtraTreesClassifier               0.88               0.87     0.87      0.88
# DecisionTreeClassifier             0.88               0.87     0.87      0.88
# RidgeClassifierCV                  0.87               0.86     0.86      0.87
# RidgeClassifier                    0.87               0.86     0.86      0.87
# LinearDiscriminantAnalysis         0.87               0.86     0.86      0.87
# LinearSVC                          0.87               0.86     0.86      0.86
# LogisticRegression                 0.87               0.86     0.86      0.86
# NuSVC                              0.86               0.85     0.85      0.86
# CalibratedClassifierCV             0.86               0.85     0.85      0.86
# SVC                                0.85               0.84     0.84      0.85
# NearestCentroid                    0.81               0.82     0.82      0.82
# KNeighborsClassifier               0.82               0.81     0.81      0.82
# LabelSpreading                     0.80               0.81     0.81      0.80
# LabelPropagation                   0.80               0.81     0.81      0.80
# BernoulliNB                        0.79               0.79     0.79      0.80
# QuadraticDiscriminantAnalysis      0.77               0.79     0.79      0.77
# ExtraTreeClassifier                0.80               0.79     0.79      0.80
# SGDClassifier                      0.81               0.79     0.79      0.81
# PassiveAggressiveClassifier        0.77               0.76     0.76      0.77
# Perceptron                         0.76               0.74     0.74      0.75
# GaussianNB                         0.70               0.73     0.73      0.70
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# XGBClassifier                        0.12
# LGBMClassifier                       0.09
# AdaBoostClassifier                   0.18
# RandomForestClassifier               0.16
# BaggingClassifier                    0.07
# ExtraTreesClassifier                 0.16
# DecisionTreeClassifier               0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.01
# LinearDiscriminantAnalysis           0.03
# LinearSVC                            0.05
# LogisticRegression                   0.03
# NuSVC                                0.05
# CalibratedClassifierCV               0.18
# SVC                                  0.03
# NearestCentroid                      0.02
# KNeighborsClassifier                 0.02
# LabelSpreading                       0.05
# LabelPropagation                     0.04
# BernoulliNB                          0.01
# QuadraticDiscriminantAnalysis        0.02
# ExtraTreeClassifier                  0.01
# SGDClassifier                        0.01
# PassiveAggressiveClassifier          0.02
# Perceptron                           0.02
# GaussianNB                           0.01
# DummyClassifier                      0.01
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 20.02it/s]
# [LightGBM] [Info] Number of positive: 370, number of negative: 254
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1564
# [LightGBM] [Info] Number of data points in the train set: 624, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.592949 -> initscore=0.376169
# [LightGBM] [Info] Start training from score 0.376169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 0.93               0.92     0.92      0.93
# LGBMClassifier                     0.92               0.91     0.91      0.92
# XGBClassifier                      0.92               0.91     0.91      0.92
# BaggingClassifier                  0.90               0.90     0.90      0.90
# SGDClassifier                      0.90               0.89     0.89      0.90
# RandomForestClassifier             0.89               0.88     0.88      0.89
# SVC                                0.88               0.87     0.87      0.88
# ExtraTreesClassifier               0.88               0.87     0.87      0.88
# NuSVC                              0.87               0.85     0.85      0.86
# DecisionTreeClassifier             0.85               0.85     0.85      0.85
# RidgeClassifierCV                  0.85               0.84     0.84      0.85
# RidgeClassifier                    0.85               0.84     0.84      0.85
# LinearDiscriminantAnalysis         0.85               0.84     0.84      0.85
# NearestCentroid                    0.83               0.83     0.83      0.83
# Perceptron                         0.85               0.83     0.83      0.85
# LinearSVC                          0.83               0.83     0.83      0.83
# CalibratedClassifierCV             0.83               0.82     0.82      0.83
# PassiveAggressiveClassifier        0.85               0.82     0.82      0.84
# LogisticRegression                 0.83               0.82     0.82      0.83
# ExtraTreeClassifier                0.81               0.81     0.81      0.82
# LabelSpreading                     0.77               0.78     0.78      0.77
# LabelPropagation                   0.77               0.78     0.78      0.77
# QuadraticDiscriminantAnalysis      0.74               0.77     0.77      0.74
# KNeighborsClassifier               0.77               0.76     0.76      0.77
# GaussianNB                         0.71               0.74     0.74      0.70
# BernoulliNB                        0.73               0.72     0.72      0.73
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.13
# LGBMClassifier                       0.08
# XGBClassifier                        0.13
# BaggingClassifier                    0.06
# SGDClassifier                        0.01
# RandomForestClassifier               0.21
# SVC                                  0.05
# ExtraTreesClassifier                 0.15
# NuSVC                                0.04
# DecisionTreeClassifier               0.03
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.02
# LinearDiscriminantAnalysis           0.02
# NearestCentroid                      0.01
# Perceptron                           0.01
# LinearSVC                            0.05
# CalibratedClassifierCV               0.19
# PassiveAggressiveClassifier          0.01
# LogisticRegression                   0.02
# ExtraTreeClassifier                  0.02
# LabelSpreading                       0.04
# LabelPropagation                     0.03
# QuadraticDiscriminantAnalysis        0.02
# KNeighborsClassifier                 0.02
# GaussianNB                           0.01
# BernoulliNB                          0.02
# DummyClassifier                      0.02
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 20.55it/s]
# [LightGBM] [Info] Number of positive: 371, number of negative: 253
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000241 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1562
# [LightGBM] [Info] Number of data points in the train set: 624, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.594551 -> initscore=0.382813
# [LightGBM] [Info] Start training from score 0.382813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.92               0.92     0.92      0.92
# LGBMClassifier                     0.90               0.90     0.90      0.90
# AdaBoostClassifier                 0.89               0.89     0.89      0.89
# RandomForestClassifier             0.89               0.89     0.89      0.89
# BaggingClassifier                  0.87               0.87     0.87      0.87
# DecisionTreeClassifier             0.87               0.86     0.86      0.87
# ExtraTreesClassifier               0.86               0.85     0.85      0.86
# NuSVC                              0.86               0.85     0.85      0.86
# LogisticRegression                 0.85               0.85     0.85      0.85
# SVC                                0.85               0.85     0.85      0.85
# LinearSVC                          0.85               0.84     0.84      0.85
# CalibratedClassifierCV             0.84               0.84     0.84      0.84
# Perceptron                         0.84               0.83     0.83      0.84
# LinearDiscriminantAnalysis         0.83               0.83     0.83      0.83
# RidgeClassifier                    0.83               0.83     0.83      0.83
# RidgeClassifierCV                  0.83               0.83     0.83      0.83
# NearestCentroid                    0.81               0.82     0.82      0.82
# QuadraticDiscriminantAnalysis      0.78               0.78     0.78      0.78
# BernoulliNB                        0.79               0.78     0.78      0.79
# ExtraTreeClassifier                0.78               0.78     0.78      0.78
# GaussianNB                         0.76               0.78     0.78      0.76
# KNeighborsClassifier               0.78               0.77     0.77      0.78
# SGDClassifier                      0.76               0.76     0.76      0.76
# LabelSpreading                     0.72               0.72     0.72      0.72
# LabelPropagation                   0.72               0.72     0.72      0.72
# PassiveAggressiveClassifier        0.72               0.71     0.71      0.72
# DummyClassifier                    0.59               0.50     0.50      0.44
#
#                                Time Taken
# Model
# XGBClassifier                        0.13
# LGBMClassifier                       0.08
# AdaBoostClassifier                   0.15
# RandomForestClassifier               0.20
# BaggingClassifier                    0.06
# DecisionTreeClassifier               0.03
# ExtraTreesClassifier                 0.13
# NuSVC                                0.03
# LogisticRegression                   0.03
# SVC                                  0.05
# LinearSVC                            0.05
# CalibratedClassifierCV               0.15
# Perceptron                           0.01
# LinearDiscriminantAnalysis           0.03
# RidgeClassifier                      0.02
# RidgeClassifierCV                    0.02
# NearestCentroid                      0.01
# QuadraticDiscriminantAnalysis        0.01
# BernoulliNB                          0.01
# ExtraTreeClassifier                  0.01
# GaussianNB                           0.02
# KNeighborsClassifier                 0.03
# SGDClassifier                        0.01
# LabelSpreading                       0.05
# LabelPropagation                     0.03
# PassiveAggressiveClassifier          0.01
# DummyClassifier                      0.01
# 100%|██████████████████████████████████████████| 29/29 [00:01<00:00, 22.12it/s]
# [LightGBM] [Info] Number of positive: 371, number of negative: 253
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1575
# [LightGBM] [Info] Number of data points in the train set: 624, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.594551 -> initscore=0.382813
# [LightGBM] [Info] Start training from score 0.382813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.94               0.93     0.93      0.94
# XGBClassifier                      0.92               0.93     0.93      0.92
# LGBMClassifier                     0.92               0.92     0.92      0.92
# ExtraTreesClassifier               0.92               0.91     0.91      0.92
# AdaBoostClassifier                 0.92               0.91     0.91      0.92
# BaggingClassifier                  0.90               0.90     0.90      0.90
# SVC                                0.90               0.90     0.90      0.90
# NuSVC                              0.90               0.89     0.89      0.90
# LogisticRegression                 0.89               0.88     0.88      0.89
# LinearSVC                          0.88               0.88     0.88      0.88
# CalibratedClassifierCV             0.88               0.87     0.87      0.88
# DecisionTreeClassifier             0.87               0.87     0.87      0.87
# LinearDiscriminantAnalysis         0.87               0.87     0.87      0.87
# RidgeClassifier                    0.87               0.87     0.87      0.87
# RidgeClassifierCV                  0.87               0.87     0.87      0.87
# Perceptron                         0.85               0.84     0.84      0.85
# NearestCentroid                    0.83               0.83     0.83      0.83
# SGDClassifier                      0.84               0.83     0.83      0.84
# PassiveAggressiveClassifier        0.81               0.81     0.81      0.81
# BernoulliNB                        0.79               0.79     0.79      0.79
# ExtraTreeClassifier                0.79               0.78     0.78      0.79
# KNeighborsClassifier               0.79               0.78     0.78      0.79
# GaussianNB                         0.72               0.74     0.74      0.72
# QuadraticDiscriminantAnalysis      0.72               0.74     0.74      0.72
# LabelPropagation                   0.71               0.71     0.71      0.71
# LabelSpreading                     0.71               0.71     0.71      0.71
# DummyClassifier                    0.59               0.50     0.50      0.44
#
#                                Time Taken
# Model
# RandomForestClassifier               0.22
# XGBClassifier                        0.13
# LGBMClassifier                       0.07
# ExtraTreesClassifier                 0.13
# AdaBoostClassifier                   0.11
# BaggingClassifier                    0.07
# SVC                                  0.03
# NuSVC                                0.04
# LogisticRegression                   0.03
# LinearSVC                            0.04
# CalibratedClassifierCV               0.14
# DecisionTreeClassifier               0.03
# LinearDiscriminantAnalysis           0.02
# RidgeClassifier                      0.01
# RidgeClassifierCV                    0.02
# Perceptron                           0.01
# NearestCentroid                      0.01
# SGDClassifier                        0.01
# PassiveAggressiveClassifier          0.01
# BernoulliNB                          0.02
# ExtraTreeClassifier                  0.01
# KNeighborsClassifier                 0.01
# GaussianNB                           0.02
# QuadraticDiscriminantAnalysis        0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.04
# DummyClassifier                      0.01
